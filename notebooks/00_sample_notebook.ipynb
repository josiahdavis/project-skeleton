# %% [markdown]
# # Sample Notebook

# %%
from src.data import list_objects, download_objects
from src.visualization import plot, bar, hist
import random

# %%
n_pts = 15
x = list(range(n_pts))
y1 = [random.random() for _ in range(n_pts)]
y2 = [random.random() for _ in range(n_pts)]
y3 = [random.random() for _ in range(n_pts)]

ax = plot(
    [x], 
    [y1, y2, y3], 
    ['Kingfishers', 'Ospreys', 'Crowned Eagles'], 
    xlab='Wing Span', 
    ylab='Diving Speed', 
    href=0.75, 
    grid=False, 
    marker_type="o-"
)

# %%
n_grps = 6
x = [f'G{i}' for i in range(n_grps)]
y1 = [random.random() for _ in range(n_grps)]
y2 = [random.random() for _ in range(n_grps)]
y3 = [random.random() for _ in range(n_grps)]

ax = bar(
    x, 
    [y1, y2, y3], 
    ['Kingfishers', 'Ospreys', 'Crowned Eagles'], 
    'Wing Span', 
    'Diving Speed', 
)
