# %%
from src.visualization import scatter_plot

# %%
import random
x = list(range(10))
y1 = [random.random() for _ in range(10)]
y2 = [random.random() for _ in range(10)]
y3 = [random.random() for _ in range(10)]

# %%
scatter_plot(x, [y1, y2, y3], ['cats', 'dogs', 'kangaroos'], 'weight', 'height')

# %%
scatter_plot(x, [y1, y2, y3], ['cats', 'dogs', 'kangaroos'], 'weight', 'height', grid=True)

# %%
href = 0.75
scatter_plot(x, [y1, y2, y3], ['cats', 'dogs', 'kangaroos'], 'weight', 'height', href=href)
