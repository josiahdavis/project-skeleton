# %%
from src.visualization import scatter_plot

# %%
import random
x = list(range(10))
y1 = [random.random() for _ in range(10)]
y2 = [random.random() for _ in range(10)]
y3 = [random.random() for _ in range(10)]
y4 = [random.random() for _ in range(10)]
y5 = [random.random() for _ in range(10)]

# %%
scatter_plot(x, [y1, y2, y3], ['cats', 'dogs', 'kangaroos'], 'weight', 'height', href=0.75, grid=True)

# %%
from src.visualization import bar_plot

x = [f'G{i}' for i in range(10)]

# %%
bar_plot(x, [y1, y2, y3], ['cats', 'dogs', 'puppies'], 'weight', 'height')
